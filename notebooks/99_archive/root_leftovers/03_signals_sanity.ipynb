# %%
from src.core.pipeline import run_pipeline

df = run_pipeline("austin")

df[[
    "dti_z",
    "pti_z",
    "rent_burden_z",
    "supply_pressure_z",
    "migration_pressure_z"
]].std()
# Out:
# dti_z                   1.002614
# pti_z                   1.002614
# rent_burden_z           1.002614
# supply_pressure_z       1.002614
# migration_pressure_z    1.002614
# dtype: float64

# %%
df["score_xs"].describe()
# Out:
# count    1.920000e+02
# mean    -2.590520e-16
# std      5.981662e-01
# min     -1.524245e+00
# 25%     -4.025527e-01
# 50%      3.521050e-02
# 75%      4.666248e-01
# max      1.295156e+00
# Name: score_xs, dtype: float64

# %% [markdown]
# The composite score exhibits stable time-series variation and a well-behaved distribution.

# %% [markdown]
# ## Signal Construction Sanity Check
#
# This section validates that the affordability signal is mathematically identifiable
# after time-series normalization within each metro.
