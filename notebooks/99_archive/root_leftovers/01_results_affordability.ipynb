# %%
import pandas as pd
import matplotlib.pyplot as plt

from src.pipeline import run_pipeline
from src.evaluation import (
    compute_forward_return,
    compute_ic,
    directional_backtest,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 from src.pipeline import run_pipeline
#       5 from src.evaluation import (
#       6     compute_forward_return,
#       7     compute_ic,
#       8     directional_backtest,
#       9 )
#
# File ~/Mispricing Model_Leviathan/leviathan-model/src/pipeline.py:20
#      17     df = build_affordability_signal(df)
#      18     return df
# ---> 20 from src.features.affordability import (
#      21     attach_affordability_features,
#      22     build_affordability_score
#      23 )
#      25 def run_pipeline(region: str):
#      26     df = load_housing_data(region)
#
# ImportError: cannot import name 'build_affordability_score' from 'src.features.affordability' (/Users/axl/Mispricing Model_Leviathan/leviathan-model/src/features/affordability.py)
